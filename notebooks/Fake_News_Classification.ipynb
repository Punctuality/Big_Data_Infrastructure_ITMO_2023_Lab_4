# %% [markdown]
# ## Download dataset

# %%
# !pip3 install kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c 'fake-news'
# !mv fake-news.zip ../tmp/
# !unzip ../tmp/fake-news.zip -d ../tmp/fake-news
# !rm ../tmp/fake-news.zip
# Out:
# Requirement already satisfied: kaggle in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (1.5.13)
# Requirement already satisfied: six>=1.10 in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-dateutil in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from kaggle) (2.28.2)
# Requirement already satisfied: tqdm in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from kaggle) (1.26.15)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from requests->kaggle) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sdfedorov/.ml_python_venv/lib/python3.11/site-packages (from requests->kaggle) (3.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Downloading fake-news.zip to /Users/sdfedorov/Documents/ITMO/Master/2 semester/Big_Data_Infrastructure_ITMO_2023/Lab1/notebooks
#  97%|████████████████████████████████████▊ | 45.0M/46.5M [00:06<00:00, 10.6MB/s]
# 100%|██████████████████████████████████████| 46.5M/46.5M [00:06<00:00, 7.84MB/s]
# Archive:  ../tmp/fake-news.zip
#   inflating: ../tmp/fake-news/submit.csv
#   inflating: ../tmp/fake-news/test.csv
#   inflating: ../tmp/fake-news/train.csv

# %% [markdown]
# ## Data preprocessing

# %%
import pandas as pd

import torch as t
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import nltk
import re
from nltk.corpus import stopwords

# %%
def optimal_device():
    if t.cuda.is_available():
        return t.device('cuda')
    else:
        try:
            return t.device('mps')
        except:
            return t.device('cpu')

# %%
data_dir = "../tmp/fake-news/"
df = pd.read_csv(f'{data_dir}/train.csv')
test = pd.read_csv(f'{data_dir}/test.csv')

df.head()
# Out:
#    id                                              title              author
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus  \
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
df = df.fillna('')
test = test.fillna('')

df['total'] = df['title']+' '+df['author']
test['total']=test['title']+' '+test['author']

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(df.drop('label', axis=1), df['label'], test_size=0.2, random_state=42)

# %%
#Choosing vocabulary size to be 5000 and copying data to msg for further cleaning
voc_size = 5000
X_train = X_train.copy()
X_val = X_val.copy()
X_test = test.copy()

# %%
#Downloading stopwords 
#Stopwords are the words in any language which does not add much meaning to a sentence.
#They can safely be ignored without sacrificing the meaning of the sentence.
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sdfedorov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#We will be using Stemming here
#Stemming map words to their root forms
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
import time

def measure_time(callable, name):
    def wrapper():
        start = time.time()
        result = callable()
        end = time.time()
        print(f"Time elapsed ({name}): {end - start}")
        return result

    return wrapper

def construct_corpus(data):
    corpus = []
    for i in tqdm(range(len(data))):
        review = re.sub('[^a-zA-Z]',' ', data['total'].iloc[i])
        review = review.lower()
        review = review.split()
        review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
        review = ' '.join(review)
        corpus.append(review)
    return corpus

# %%
from typing import Union, Iterable
import torchtext
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

tokenizer = get_tokenizer("basic_english")

corpus = construct_corpus(X_train)
corpus_test = construct_corpus(X_test)
corpus_val = construct_corpus(X_val)

tokens = [tokenizer(doc) for doc in corpus]
tokens_val = [tokenizer(doc) for doc in corpus_val]
tokens_test = [tokenizer(doc) for doc in corpus_test]
voc = build_vocab_from_iterator(tokens + tokens_val, max_tokens=voc_size, specials=["<unk>"])
voc.set_default_index(voc["<unk>"])

voc_tokens = [t.tensor(voc(token), dtype=t.int64) for token in tokens]
voc_tokens_val = [t.tensor(voc(token), dtype=t.int64) for token in tokens_val]
voc_tokens_test = [t.tensor(voc(token), dtype=t.int64) for token in tokens_test]
# Out:
#   0%|          | 0/16640 [00:00<?, ?it/s]
# Review len 18
# Review len 20
# Review len 18
# Review len 20
# Review len 15
# Review len 16
# Review len 7
# Review len 6
# Review len 12
# Review len 19
# Review len 9
# Review len 16
# Review len 15
# Review len 0
# Review len 11
# Review len 12
# Review len 15
# Review len 17
# Review len 8
# Review len 17
# Review len 11
# Review len 14
# Review len 9
# Review len 11
# Review len 0
# Review len 15
# Review len 14
# Review len 23
# Review len 15
# Review len 17
# Review len 11
# Review len 19
# Review len 20
# Review len 21
# Review len 15
# Review len 15
# Review len 20
# Review len 8
# Review len 21
# Review len 9
# Review len 11
# Review len 17
# Review len 15
# Review len 12
# Review len 10
# Review len 16
# Review len 12
# Review len 14
# Review len 13
# Review len 16
# Review len 13
# Review len 15
# Review len 16
# Review len 16
# Review len 25
# Review len 21
# Review len 9
# Review len 19
# Review len 16
# Review len 17
# Review len 15
# Review len 17
# Review len 20
# Review len 17
# Review len 11
# Review len 16
# Review len 23
# Review len 9
# Review len 19
# Review len 18
# Review len 21
# Review len 23
# Review len 21
# Review len 18
# Review len 17
# Review len 8
# Review len 16
# Review len 13
# Review len 9
# Review len 18
# Review len 13
# Review len 13
# Review len 17
# Review len 18
# Review len 17
# Review len 20
# Review len 12
# Review len 15
# Review len 2
# Review len 17
# Review len 11
# Review len 14
# Review len 7
# Review len 11
# Review len 16
# Review len 15
# Review len 31
# Review len 17
# Review len 22
# Review len 16
# Review len 18
# Review len 7
# Review len 9
# Review len 9
# Review len 15
# Review len 16
# Review len 17
# Review len 13
# Review len 17
# Review len 11
# Review len 11
# Review len 18
# Review len 6
# Review len 9
# Review len 12
# Review len 11
# Review len 21
# Review len 17
# Review len 14
# Review len 18
# Review len 19
# Review len 15
# Review len 20
# Review len 20
# Review len 8
# Review len 11
# Review len 16
# Review len 14
# Review len 12
# Review len 16
# Review len 14
# Review len 16
# Review len 17
# Review len 19
# Review len 16
# Review len 3
# Review len 12
# Review len 13
# Review len 9
# Review len 13
# Review len 19
# Review len 14
# Review len 15
# Review len 1
# Review len 14
# Review len 11
# Review len 15
# Review len 21
# Review len 14
# Review len 15
# Review len 13
# Review len 13
# Review len 10
# Review len 16
# Review len 17
# Review len 11
# Review len 14
# Review len 17
# Review len 21
# Review len 14
# Review len 15
# Review len 19
# Review len 11
# Review len 18
# Review len 22
# Review len 12
# Review len 14
# Review len 15
# Review len 13
# Review len 18
# Review len 16
# Review len 18
# Review len 17
# Review len 12
# Review len 19
# Review len 11
# Review len 8
# Review len 14
# Review len 18
# Review len 10
# Review len 6
# Review len 16
# Review len 12
# Review len 18
# Review len 13
# Review len 11
# Review len 16
# Review len 6
# Review len 14
# Review len 13
# Review len 16
# Review len 18
# Review len 17
# Review len 7
# Review len 14
# Review len 7
# Review len 9
# Review len 16
# Review len 16
# Review len 16
# Review len 17
# Review len 10
# Review len 14
# Review len 19
# Review len 19
# Review len 14
# Review len 8
# Review len 9
# Review len 11
# Review len 15
# Review len 19
# Review len 8
# Review len 14
# Review len 19
# Review len 19
# Review len 19
# Review len 18
# Review len 17
# Review len 14
# Review len 2
# Review len 4
# Review len 9
# Review len 14
# Review len 14
# Review len 10
# Review len 18
# Review len 5
# Review len 1
# Review len 11
# Review len 11
# Review len 12
# Review len 12
# Review len 12
# Review len 15
# Review len 12
# Review len 20
# Review len 10
# Review len 9
# Review len 14
# Review len 13
# Review len 11
# Review len 12
# Review len 13
# Review len 19
# Review len 9
# Review len 22
# Review len 14
# Review len 10
# Review len 14
# Review len 17
# Review len 12
# Review len 0
# Review len 19
# Review len 7
# Review len 14
# Review len 12
# Review len 8
# Review len 16
# Review len 18
# Review len 23
# Review len 16
# Review len 3
# Review len 15
# Review len 14
# Review len 1
# Review len 1
# Review len 7
# Review len 14
# Review len 17
# Review len 12
# Review len 12
# Review len 14
# Review len 13
# Review len 13
# Review len 14
# Review len 14
# Review len 18
# Review len 14
# Review len 15
# Review len 12
# Review len 15
# Review len 15
# Review len 16
# Review len 21
# Review len 12
# Review len 20
# Review len 14
# Review len 3
# Review len 11
# Review len 18
# Review len 20
# Review len 13
# Review len 21
# Review len 15
# Review len 19
# Review len 13
# Review len 17
# Review len 15
# Review len 17
# Review len 16
# Review len 12
# Review len 22
# Review len 12
# Review len 14
# Review len 22
# Review len 15
# Review len 10
# Review len 12
# Review len 11
# Review len 8
# Review len 12
# Review len 1
# Review len 10
# Review len 25
# Review len 12
# Review len 18
# Review len 15
# Review len 2
# Review len 16
# Review len 12
# Review len 10
# Review len 17
# Review len 16
# Review len 16
# Review len 7
# Review len 15
# Review len 11
# Review len 17
# Review len 8
# Review len 12
# Review len 19
# Review len 10
# Review len 14
# Review len 13
# Review len 14
# Review len 19
# Review len 18
# Review len 14
# Review len 23
# Review len 16
# Review len 16
# Review len 16
# Review len 29
# Review len 12
# Review len 11
# Review len 8
# Review len 14
# Review len 21
# Review len 14
# Review len 12
# Review len 19
# Review len 13
# Review len 17
# Review len 19
# Review len 10
# Review len 16
# Review len 13
# Review len 21
# Review len 10
# Review len 14
# Review len 19
# Review len 17
# Review len 13
# Review len 2
# Review len 10
# Review len 1
# Review len 13
# Review len 14
# Review len 17
# Review len 9
# Review len 14
# Review len 16
# Review len 14
# Review len 17
# Review len 17
# Review len 16
# Review len 19
# Review len 13
# Review len 14
# Review len 9
# Review len 13
# Review len 27
# Review len 9
# Review len 26
# Review len 17
# Review len 17
# Review len 14
# Review len 11
# Review len 9
# Review len 9
# Review len 20
# Review len 11
# Review len 15
# Review len 10
# Review len 24
# Review len 13
# Review len 26
# Review len 20
# Review len 9
# Review len 28
# Review len 17
# Review len 16
# Review len 11
# Review len 16
# Review len 14
# Review len 42
# Review len 15
# Review len 13
# Review len 18
# Review len 14
# Review len 16
# Review len 14
# Review len 11
# Review len 14
# Review len 12
# Review len 7
# Review len 11
# Review len 14
# Review len 11
# Review len 17
# Review len 16
# Review len 13
# Review len 18
# Review len 16
# Review len 11
# Review len 20
# Review len 12
# Review len 16
# Review len 10
# Review len 10
# Review len 15
# Review len 18
# Review len 15
# Review len 8
# Review len 14
# Review len 9
# Review len 11
# Review len 17
# Review len 16
# Review len 16
# Review len 16
# Review len 18
# Review len 15
# Review len 19
# Review len 12
# Review len 1
# Review len 17
# Review len 13
# Review len 15
# Review len 9
# Review len 7
# Review len 15
# Review len 27
# Review len 9
# Review len 11
# Review len 21
# Review len 17
# Review len 10
# Review len 15
# Review len 16
# Review len 12
# Review len 18
# Review len 10
# Review len 13
# Review len 12
# Review len 13
# Review len 13
# Review len 14
# Review len 18
# Review len 14
# Review len 18
# Review len 17
# Review len 15
# Review len 17
# Review len 10
# Review len 11
# Review len 20
# Review len 9
# Review len 14
# Review len 25
# Review len 16
# Review len 18
# Review len 19
# Review len 14
# Review len 7
# Review len 18
# Review len 18
# Review len 15
# Review len 15
# Review len 11
# Review len 14
# Review len 20
# Review len 13
# Review len 9
# Review len 2
# Review len 19
# Review len 11
# Review len 15
# Review len 10
# Review len 1
# Review len 13
# Review len 17
# Review len 10
# Review len 17
# Review len 9
# Review len 0
# Review len 1
# Review len 22
# Review len 8
# Review len 5
# Review len 15
# Review len 22
# Review len 7
# Review len 14
# Review len 20
# Review len 16
# Review len 19
# Review len 12
# Review len 20
# Review len 14
# Review len 7
# Review len 17
# Review len 1
# Review len 13
# Review len 14
# Review len 10
# Review len 8
# Review len 14
# Review len 18
# Review len 15
# Review len 17
# Review len 22
# Review len 10
# Review len 20
# Review len 17
# Review len 4
# Review len 19
# Review len 15
# Review len 25
# Review len 12
# Review len 13
# Review len 15
# Review len 12
# Review len 13
# Review len 20
# Review len 1
# Review len 16
# Review len 12
# Review len 12
# Review len 16
# Review len 13
# Review len 10
# Review len 16
# Review len 11
# Review len 18
# Review len 12
# Review len 16
# Review len 19
# Review len 22
# Review len 10
# Review len 15
# Review len 13
# Review len 21
# Review len 16
# Review len 14
# Review len 21
# Review len 15
# Review len 17
# Review len 4
# Review len 12
# Review len 17
# Review len 18
# Review len 20
# Review len 15
# Review len 18
# Review len 17
# Review len 10
# Review len 14
# Review len 19
# Review len 11
# Review len 14
# Review len 12
# Review len 16
# Review len 27
# Review len 1
# Review len 5
# Review len 9
# Review len 11
# Review len 12
# Review len 15
# Review len 11
# Review len 14
# Review len 10
# Review len 13
# Review len 21
# Review len 1
# Review len 21
# Review len 20
# Review len 15
# Review len 26
# Review len 16
# Review len 11
# Review len 22
# Review len 25
# Review len 12
# Review len 22
# Review len 8
# Review len 15
# Review len 15
# Review len 9
# Review len 23
# Review len 11
# Review len 6
# Review len 16
# Review len 22
# Review len 11
# Review len 8
# Review len 15
# Review len 16
# Review len 21
# Review len 11
# Review len 16
# Review len 13
# Review len 18
# Review len 11
# Review len 15
# Review len 14
# Review len 18
# Review len 13
# Review len 14
# Review len 7
# Review len 18
# Review len 15
# Review len 20
# Review len 10
# Review len 15
# Review len 15
# Review len 17
# Review len 20
# Review len 20
# Review len 6
# Review len 3
# Review len 3
# Review len 11
# Review len 18
# Review len 13
# Review len 12
# Review len 14
# Review len 18
# Review len 16
# Review len 7
# Review len 6
# Review len 13
# Review len 16
# Review len 12
# Review len 9
# Review len 13
# Review len 18
# Review len 14
# Review len 12
# Review len 15
# Review len 15
# Review len 18
# Review len 9
# Review len 10
# Review len 6
# Review len 13
# Review len 16
# Review len 18
# Review len 12
# Review len 16
# Review len 14
# Review len 17
# Review len 13
# Review len 16
# Review len 11
# Review len 17
# Review len 12
# Review len 11
# Review len 18
# Review len 10
# Review len 9
# Review len 16
# Review len 8
# Review len 16
# Review len 17
# Review len 16
# Review len 2
# Review len 14
# Review len 12
# Review len 19
# Review len 18
# Review len 16
# Review len 19
# Review len 20
# Review len 11
# Review len 16
# Review len 16
# Review len 8
# Review len 19
# Review len 12
# Review len 16
# Review len 7
# Review len 12
# Review len 20
# Review len 7
# Review len 12
# Review len 12
# Review len 11
# Review len 15
# Review len 17
# Review len 15
# Review len 18
# Review len 19
# Review len 17
# Review len 22
# Review len 15
# Review len 20
# Review len 12
# Review len 14
# Review len 22
# Review len 17
# Review len 14
# Review len 5
# Review len 12
# Review len 18
# Review len 17
# Review len 19
# Review len 11
# Review len 19
# Review len 19
# Review len 14
# Review len 2
# Review len 22
# Review len 16
# Review len 20
# Review len 10
# Review len 20
# Review len 19
# Review len 10
# Review len 10
# Review len 15
# Review len 9
# Review len 12
# Review len 16
# Review len 25
# Review len 15
# Review len 13
# Review len 13
# Review len 4
# Review len 8
# Review len 12
# Review len 12
# Review len 13
# Review len 13
# Review len 1
# Review len 6
# Review len 18
# Review len 15
# Review len 21
# Review len 14
# Review len 13
# Review len 14
# Review len 16
# Review len 3
# Review len 16
# Review len 17
# Review len 17
# Review len 22
# Review len 14
# Review len 17
# Review len 18
# Review len 13
# Review len 21
# Review len 18
# Review len 11
# Review len 10
# Review len 12
# Review len 21
# Review len 16
# Review len 14
# Review len 12
# Review len 12
# Review len 10
# Review len 14
# Review len 16
# Review len 18
# Review len 19
# Review len 12
# Review len 9
# Review len 3
# Review len 18
# Review len 20
# Review len 14
# Review len 11
# Review len 11
# Review len 10
# Review len 11
# Review len 17
# Review len 22
# Review len 15
# Review len 15
# Review len 0
# Review len 11
# Review len 19
# Review len 18
# Review len 24
# Review len 15
# Review len 18
# Review len 15
# Review len 8
# Review len 20
# Review len 15
# Review len 13
# Review len 1
# Review len 9
# Review len 1
# Review len 16
# Review len 27
# Review len 9
# Review len 11
# Review len 18
# Review len 11
# Review len 1
# Review len 16
# Review len 9
# Review len 8
# Review len 23
# Review len 16
# Review len 11
# Review len 17
# Review len 16
# Review len 15
# Review len 12
# Review len 15
# Review len 8
# Review len 6
# Review len 0
# Review len 15
# Review len 15
# Review len 17
# Review len 16
# Review len 7
# Review len 18
# Review len 21
# Review len 2
# Review len 14
# Review len 20
# Review len 8
# Review len 8
# Review len 12
# Review len 12
# Review len 15
# Review len 13
# Review len 13
# Review len 19
# Review len 11
# Review len 19
# Review len 17
# Review len 15
# Review len 19
# Review len 7
# Review len 15
# Review len 8
# Review len 18
# Review len 17
# Review len 11
# Review len 19
# Review len 15
# Review len 13
# Review len 18
# Review len 13
# Review len 13
# Review len 13
# Review len 12
# Review len 11
# Review len 23
# Review len 10
# Review len 19
# Review len 10
# Review len 7
# Review len 23
# Review len 9
# Review len 19
# Review len 9
# Review len 16
# Review len 9
# Review len 26
# Review len 14
# Review len 17
# Review len 1
# Review len 12
# Review len 23
# Review len 15
# Review len 18
# Review len 21
# Review len 18
# Review len 15
# Review len 16
# Review len 17
# Review len 11
# Review len 13
# Review len 9
# Review len 17
# Review len 16
# Review len 22
# Review len 7
# Review len 22
# Review len 15
# Review len 15
# Review len 14
# Review len 19
# Review len 17
# Review len 1
# Review len 10
# Review len 7
# Review len 2
# Review len 12
# Review len 9
# Review len 6
# Review len 14
# Review len 13
# Review len 14
# Review len 12
# Review len 19
# Review len 12
# Review len 15
# Review len 13
# Review len 10
# Review len 13
# Review len 15
# Review len 16
# Review len 14
# Review len 11
# Review len 20
# Review len 18
# Review len 11
# Review len 19
# Review len 25
# Review len 10
# Review len 10
# Review len 16
# Review len 20
# Review len 8
# Review len 20
# Review len 19
# Review len 29
# Review len 9
# Review len 8
# Review len 52
# Review len 14
# Review len 17
# Review len 15
# Review len 18
# Review len 15
# Review len 8
# Review len 9
# Review len 23
# Review len 11
# Review len 11
# Review len 11
# Review len 16
# Review len 12
# Review len 15
# Review len 17
# Review len 14
# Review len 11
# Review len 17
# Review len 18
# Review len 16
# Review len 17
# Review len 2
# Review len 9
# Review len 8
# Review len 14
# Review len 18
# Review len 11
# Review len 15
# Review len 10
# Review len 20
# Review len 16
# Review len 16
# Review len 12
# Review len 19
# Review len 12
# Review len 19
# Review len 10
# Review len 16
# Review len 12
# Review len 2
# Review len 8
# Review len 15
# Review len 19
# Review len 17
# Review len 11
# Review len 20
# Review len 13
# Review len 16
# Review len 7
# Review len 15
# Review len 14
# Review len 18
# Review len 12
# Review len 21
# Review len 11
# Review len 19
# Review len 9
# Review len 19
# Review len 17
# Review len 16
# Review len 9
# Review len 21
# Review len 10
# Review len 15
# Review len 19
# Review len 8
# Review len 16
# Review len 17
# Review len 18
# Review len 15
# Review len 12
# Review len 16
# Review len 14
# Review len 17
# Review len 1
# Review len 22
# Review len 17
# Review len 22
# Review len 14
# Review len 14
# Review len 19
# Review len 10
# Review len 12
# Review len 15
# Review len 13
# Review len 22
# Review len 14
# Review len 16
# Review len 17
# Review len 16
# Review len 17
# Review len 17
# Review len 11
# Review len 16
# Review len 14
# Review len 14
# Review len 9
# Review len 13
# Review len 13
# Review len 14
# Review len 17
# Review len 11
# Review len 14
# Review len 13
# Review len 15
# Review len 14
# Review len 12
# Review len 12
# Review len 12
# Review len 11
# Review len 6
# Review len 17
# Review len 19
# Review len 9
# Review len 6
# Review len 16
# Review len 13
# Review len 17
# Review len 15
# Review len 1
# Review len 8
# Review len 9
# Review len 20
# Review len 10
# Review len 15
# Review len 16
# Review len 23
# Review len 17
# Review len 13
# Review len 13
# Review len 20
# Review len 17
# Review len 17
# Review len 12
# Review len 9
# Review len 10
# Review len 15
# Review len 1
# Review len 12
# Review len 23
# Review len 13
# Review len 1
# Review len 13
# Review len 17
# Review len 15
# Review len 20
# Review len 20
# Review len 15
# Review len 11
# Review len 14
# Review len 12
# Review len 16
# Review len 22
# Review len 16
# Review len 19
# Review len 15
# Review len 13
# Review len 20
# Review len 16
# Review len 17
# Review len 17
# Review len 24
# Review len 15
# Review len 19
# Review len 16
# Review len 19
# Review len 14
# Review len 18
# Review len 16
# Review len 8
# Review len 22
# Review len 11
# Review len 26
# Review len 17
# Review len 21
# Review len 11
# Review len 8
# Review len 7
# Review len 23
# Review len 16
# Review len 17
# Review len 10
# Review len 11
# Review len 12
# Review len 9
# Review len 8
# Review len 12
# Review len 22
# Review len 7
# Review len 17
# Review len 16
# Review len 19
# Review len 13
# Review len 13
# Review len 13
# Review len 12
# Review len 11
# Review len 8
# Review len 8
# Review len 2
# Review len 15
# Review len 11
# Review len 20
# Review len 15
# Review len 12
# Review len 17
# Review len 20
# Review len 31
# Review len 14
# Review len 10
# Review len 14
# Review len 8
# Review len 14
# Review len 5
# Review len 8
# Review len 7
# Review len 11
# Review len 9
# Review len 7
# Review len 9
# Review len 17
# Review len 12
# Review len 14
# Review len 7
# Review len 11
# Review len 16
# Review len 19
# Review len 17
# Review len 17
# Review len 8
# Review len 25
# Review len 10
# Review len 1
# Review len 11
# Review len 16
# Review len 0
# Review len 10
# Review len 17
# Review len 22
# Review len 21
# Review len 14
# Review len 11
# Review len 7
# Review len 16
# Review len 8
# Review len 12
# Review len 10
# Review len 10
# Review len 19
# Review len 7
# Review len 12
# Review len 13
# Review len 14
# Review len 16
# Review len 16
# Review len 15
# Review len 5
# Review len 16
# Review len 1
# Review len 16
# Review len 9
# Review len 18
# Review len 19
# Review len 21
# Review len 18
# Review len 22
# Review len 11
# Review len 7
# Review len 13
# Review len 10
# Review len 18
# Review len 27
# Review len 13
# Review len 10
# Review len 18
# Review len 21
# Review len 9
# Review len 8
# Review len 13
# Review len 17
# Review len 16
# Review len 12
# Review len 9
# Review len 13
# Review len 4
# Review len 5
# Review len 16
# Review len 9
# Review len 13
# Review len 15
# Review len 10
# Review len 25
# Review len 4
# Review len 14
# Review len 16
# Review len 12
# Review len 15
# Review len 16
# Review len 10
# Review len 17
# Review len 20
# Review len 15
# Review len 11
# Review len 13
# Review len 10
# Review len 13
# Review len 11
# Review len 10
# Review len 16
# Review len 14
# Review len 14
# Review len 15
# Review len 19
# Review len 9
# Review len 10
# Review len 14
# Review len 18
# Review len 13
# Review len 16
# Review len 17
# Review len 2
# Review len 10
# Review len 21
# Review len 12
# Review len 13
# Review len 16
# Review len 20
# Review len 24
# Review len 20
# Review len 8
# Review len 13
# Review len 14
# Review len 16
# Review len 12
# Review len 17
# Review len 14
# Review len 13
# Review len 12
# Review len 8
# Review len 8
# Review len 12
# Review len 15
# Review len 15
# Review len 19
# Review len 16
# Review len 14
# Review len 14
# Review len 17
# Review len 15
# Review len 18
# Review len 13
# Review len 23
# Review len 10
# Review len 17
# Review len 16
# Review len 2
# Review len 2
# Review len 18
# Review len 11
# Review len 20
# Review len 7
# Review len 14
# Review len 17
# Review len 14
# Review len 8
# Review len 15
# Review len 15
# Review len 11
# Review len 15
# Review len 18
# Review len 16
# Review len 13
# Review len 15
# Review len 19
# Review len 20
# Review len 12
# Review len 14
# Review len 10
# Review len 15
# Review len 10
# Review len 10
# Review len 13
# Review len 9
# Review len 17
# Review len 8
# Review len 15
# Review len 14
# Review len 19
# Review len 13
# Review len 1
# Review len 18
# Review len 19
# Review len 21
# Review len 17
# Review len 10
# Review len 7
# Review len 15
# Review len 17
# Review len 12
# Review len 23
# Review len 13
# Review len 17
# Review len 20
# Review len 14
# Review len 19
# Review len 13
# Review len 16
# Review len 14
# Review len 18
# Review len 15
# Review len 17
# Review len 6
# Review len 16
# Review len 12
# Review len 17
# Review len 14
# Review len 12
# Review len 18
# Review len 12
# Review len 11
# Review len 15
# Review len 21
# Review len 13
# Review len 17
# Review len 13
# Review len 14
# Review len 12
# Review len 17
# Review len 4
# Review len 15
# Review len 26
# Review len 16
# Review len 19
# Review len 8
# Review len 14
# Review len 20
# Review len 16
# Review len 15
# Review len 12
# Review len 12
# Review len 16
# Review len 11
# Review len 14
# Review len 9
# Review len 26
# Review len 21
# Review len 17
# Review len 16
# Review len 3
# Review len 11
# Review len 15
# Review len 13
# Review len 18
# Review len 10
# Review len 13
# Review len 9
# Review len 15
# Review len 16
# Review len 30
# Review len 9
# Review len 3
# Review len 20
# Review len 16
# Review len 11
# Review len 22
# Review len 19
# Review len 18
# Review len 17
# Review len 7
# Review len 12
# Review len 17
# Review len 17
# Review len 25
# Review len 14
# Review len 18
# Review len 16
# Review len 17
# Review len 14
# Review len 7
# Review len 16
# Review len 6
# Review len 21
# Review len 23
# Review len 13
# Review len 17
# Review len 16
# Review len 8
# Review len 14
# Review len 14
# Review len 14
# Review len 12
# Review len 13
# Review len 12
# Review len 1
# Review len 20
# Review len 16
# Review len 13
# Review len 18
# Review len 14
# Review len 3
# Review len 16
# Review len 10
# Review len 19
# Review len 13
# Review len 19
# Review len 16
# Review len 9
# Review len 21
# Review len 19
# Review len 9
# Review len 18
# Review len 7
# Review len 18
# Review len 3
# Review len 12
# Review len 11
# Review len 21
# Review len 13
# Review len 21
# Review len 18
# Review len 21
# Review len 11
# Review len 13
# Review len 18
# Review len 17
# Review len 14
# Review len 14
# Review len 20
# Review len 9
# Review len 11
# Review len 22
# Review len 18
# Review len 13
# Review len 10
# Review len 18
# Review len 1
# Review len 16
# Review len 10
# Review len 18
# Review len 21
# Review len 11
# Review len 13
# Review len 15
# Review len 15
# Review len 15
# Review len 14
# Review len 9
# Review len 24
# Review len 7
# Review len 14
# Review len 7
# Review len 16
# Review len 18
# Review len 13
# Review len 18
# Review len 12
# Review len 15
# Review len 15
# Review len 16
# Review len 21
# Review len 17
# Review len 6
# Review len 19
# Review len 12
# Review len 12
# Review len 25
# Review len 12
# Review len 11
# Review len 22
# Review len 12
# Review len 16
# Review len 7
# Review len 10
# Review len 0
# Review len 6
# Review len 16
# Review len 17
# Review len 8
# Review len 11
# Review len 4
# Review len 17
# Review len 12
# Review len 19
# Review len 15
# Review len 15
# Review len 13
# Review len 15
# Review len 18
# Review len 19
# Review len 18
# Review len 13
# Review len 8
# Review len 17
# Review len 10
# Review len 18
# Review len 15
# Review len 9
# Review len 12
# Review len 11
# Review len 15
# Review len 13
# Review len 15
# Review len 9
# Review len 15
# Review len 14
# Review len 11
# Review len 7
# Review len 18
# Review len 16
# Review len 15
# Review len 17
# Review len 16
# Review len 13
# Review len 10
# Review len 3
# Review len 11
# Review len 7
# Review len 9
# Review len 15
# Review len 17
# Review len 14
# Review len 16
# Review len 22
# Review len 21
# Review len 20
# Review len 22
# Review len 17
# Review len 23
# Review len 17
# Review len 11
# Review len 1
# Review len 7
# Review len 18
# Review len 20
# Review len 18
# Review len 11
# Review len 3
# Review len 12
# Review len 11
# Review len 17
# Review len 17
# Review len 10
# Review len 10
# Review len 12
# Review len 15
# Review len 6
# Review len 15
# Review len 13
# Review len 16
# Review len 20
# Review len 4
# Review len 12
# Review len 12
# Review len 15
# Review len 15
# Review len 21
# Review len 9
# Review len 16
# Review len 18
# Review len 10
# Review len 23
# Review len 8
# Review len 16
# Review len 10
# Review len 17
# Review len 20
# Review len 1
# Review len 17
# Review len 12
# Review len 14
# Review len 16
# Review len 13
# Review len 14
# Review len 2
# Review len 11
# Review len 19
# Review len 16
# Review len 14
# Review len 18
# Review len 13
# Review len 17
# Review len 16
# Review len 22
# Review len 9
# Review len 8
# Review len 11
# Review len 13
# Review len 2
# Review len 16
# Review len 14
# Review len 22
# Review len 24
# Review len 12
# Review len 21
# Review len 10
# Review len 18
# Review len 34
# Review len 12
# Review len 14
# Review len 10
# Review len 16
# Review len 15
# Review len 20
# Review len 20
# Review len 13
# Review len 16
# Review len 15
# Review len 8
# Review len 5
# Review len 17
# Review len 13
# Review len 14
# Review len 11
# Review len 16
# Review len 6
# Review len 18
# Review len 15
# Review len 11
# Review len 19
# Review len 20
# Review len 9
# Review len 7
# Review len 15
# Review len 12
# Review len 18
# Review len 11
# Review len 23
# Review len 19
# Review len 22
# Review len 18
# Review len 0
# Review len 9
# Review len 9
# Review len 19
# Review len 14
# Review len 6
# Review len 21
# Review len 11
# Review len 11
# Review len 13
# Review len 11
# Review len 8
# Review len 1
# Review len 6
# Review len 14
# Review len 9
# Review len 19
# Review len 17
# Review len 17
# Review len 19
# Review len 13
# Review len 17
# Review len 17
# Review len 13
# Review len 12
# Review len 15
# Review len 22
# Review len 13
# Review len 0
# Review len 18
# Review len 12
# Review len 16
# Review len 11
# Review len 18
# Review len 4
# Review len 12
# Review len 20
# Review len 7
# Review len 1
# Review len 22
# Review len 10
# Review len 13
# Review len 15
# Review len 20
# Review len 13
# Review len 7
# Review len 22
# Review len 17
# Review len 11
# Review len 13
# Review len 19
# Review len 1
# Review len 16
# Review len 19
# Review len 18
# Review len 16
# Review len 13
# Review len 12
# Review len 11
# Review len 18
# Review len 10
# Review len 11
# Review len 15
# Review len 17
# Review len 10
# Review len 10
# Review len 10
# Review len 12
# Review len 13
# Review len 1
# Review len 17
# Review len 10
# Review len 17
# Review len 18
# Review len 19
# Review len 8
# Review len 17
# Review len 21
# Review len 10
# Review len 11
# Review len 8
# Review len 9
# Review len 12
# Review len 2
# Review len 15
# Review len 9
# Review len 19
# Review len 16
# Review len 22
# Review len 12
# Review len 14
# Review len 23
# Review len 14
# Review len 21
# Review len 21
# Review len 22
# Review len 13
# Review len 10
# Review len 19
# Review len 19
# Review len 16
# Review len 17
# Review len 18
# Review len 20
# Review len 14
# Review len 23
# Review len 15
# Review len 12
# Review len 17
# Review len 13
# Review len 16
# Review len 20
# Review len 17
# Review len 17
# Review len 16
# Review len 21
# Review len 11
# Review len 18
# Review len 7
# Review len 10
# Review len 17
# Review len 21
# Review len 10
# Review len 12
# Review len 10
# Review len 19
# Review len 18
# Review len 19
# Review len 19
# Review len 9
# Review len 13
# Review len 16
# Review len 15
# Review len 16
# Review len 6
# Review len 10
# Review len 16
# Review len 18
# Review len 16
# Review len 11
# Review len 10
# Review len 14
# Review len 20
# Review len 12
# Review len 13
# Review len 1
# Review len 9
# Review len 13
# Review len 15
# Review len 13
# Review len 8
# Review len 12
# Review len 12
# Review len 18
# Review len 16
# Review len 10
# Review len 12
# Review len 9
# Review len 18
# Review len 16
# Review len 15
# Review len 16
# Review len 16
# Review len 12
# Review len 26
# Review len 15
# Review len 19
# Review len 8
# Review len 14
# Review len 13
# Review len 11
# Review len 7
# Review len 20
# Review len 17
# Review len 9
# Review len 12
# Review len 19
# Review len 12
# Review len 17
# Review len 17
# Review len 10
# Review len 18
# Review len 20
# Review len 10
# Review len 14
# Review len 18
# Review len 14
# Review len 9
# Review len 11
# Review len 10
# Review len 15
# Review len 6
# Review len 20
# Review len 7
# Review len 18
# Review len 17
# Review len 16
# Review len 11
# Review len 24
# Review len 13
# Review len 12
# Review len 15
# Review len 11
# Review len 10
# Review len 16
# Review len 14
# Review len 14
# Review len 13
# Review len 14
# Review len 0
# Review len 10
# Review len 14
# Review len 18
# Review len 12
# Review len 17
# Review len 12
# Review len 15
# Review len 14
# Review len 16
# Review len 8
# Review len 19
# Review len 18
# Review len 8
# Review len 10
# Review len 14
# Review len 7
# Review len 11
# Review len 6
# Review len 13
# Review len 7
# Review len 12
# Review len 14
# Review len 19
# Review len 24
# Review len 8
# Review len 13
# Review len 22
# Review len 15
# Review len 10
# Review len 9
# Review len 15
# Review len 18
# Review len 15
# Review len 18
# Review len 20
# Review len 11
# Review len 25
# Review len 15
# Review len 13
# Review len 9
# Review len 15
# Review len 13
# Review len 21
# Review len 17
# Review len 15
# Review len 19
# Review len 17
# Review len 15
# Review len 14
# Review len 22
# Review len 16
# Review len 15
# Review len 8
# Review len 16
# Review len 20
# Review len 6
# Review len 13
# Review len 15
# Review len 10
# Review len 15
# Review len 12
# Review len 10
# Review len 15
# Review len 7
# Review len 12
# Review len 14
# Review len 1
# Review len 3
# Review len 18
# Review len 12
# Review len 23
# Review len 13
# Review len 19
# Review len 8
# Review len 9
# Review len 15
# Review len 15
# Review len 17
# Review len 13
# Review len 12
# Review len 16
# Review len 15
# Review len 11
# Review len 9
# Review len 20
# Review len 17
# Review len 10
# Review len 12
# Review len 8
# Review len 16
# Review len 12
# Review len 16
# Review len 10
# Review len 23
# Review len 12
# Review len 9
# Review len 8
# Review len 16
# Review len 16
# Review len 12
# Review len 17
# Review len 8
# Review len 9
# Review len 18
# Review len 0
# Review len 18
# Review len 15
# Review len 18
# Review len 21
# Review len 16
# Review len 23
# Review len 10
# Review len 20
# Review len 7
# Review len 11
# Review len 14
# Review len 17
# Review len 18
# Review len 7
# Review len 10
# Review len 13
# Review len 16
# Review len 20
# Review len 12
# Review len 7
# Review len 7
# Review len 9
# Review len 6
# Review len 17
# Review len 11
# Review len 12
# Review len 10
# Review len 10
# Review len 5
# Review len 8
# Review len 14
# Review len 13
# Review len 17
# Review len 23
# Review len 9
# Review len 16
# Review len 22
# Review len 16
# Review len 10
# Review len 12
# Review len 5
# Review len 12
# Review len 18
# Review len 12
# Review len 6
# Review len 13
# Review len 12
# Review len 4
# Review len 6
# Review len 13
# Review len 1
# Review len 21
# Review len 23
# Review len 21
# Review len 14
# Review len 16
# Review len 24
# Review len 22
# Review len 14
# Review len 11
# Review len 11
# Review len 13
# Review len 20
# Review len 11
# Review len 18
# Review len 16
# Review len 11
# Review len 20
# Review len 17
# Review len 7
# Review len 19
# Review len 20
# Review len 13
# Review len 16
# Review len 0
# Review len 14
# Review len 6
# Review len 8
# Review len 13
# Review len 21
# Review len 12
# Review len 11
# Review len 12
# Review len 19
# Review len 8
# Review len 20
# Review len 20
# Review len 10
# Review len 11
# Review len 20
# Review len 16
# Review len 16
# Review len 19
# Review len 11
# Review len 3
# Review len 16
# Review len 13
# Review len 15
# Review len 14
# Review len 13
# Review len 17
# Review len 8
# Review len 11
# Review len 12
# Review len 14
# Review len 14
# Review len 13
# Review len 21
# Review len 8
# Review len 17
# Review len 15
# Review len 5
# Review len 7
# Review len 2
# Review len 13
# Review len 14
# Review len 12
# Review len 10
# Review len 19
# Review len 20
# Review len 1
# Review len 18
# Review len 4
# Review len 16
# Review len 15
# Review len 16
# Review len 12
# Review len 7
# Review len 23
# Review len 9
# Review len 17
# Review len 18
# Review len 16
# Review len 13
# Review len 22
# Review len 19
# Review len 16
# Review len 11
# Review len 9
# Review len 15
# Review len 18
# Review len 13
# Review len 5
# Review len 11
# Review len 17
# Review len 9
# Review len 11
# Review len 14
# Review len 11
# Review len 16
# Review len 13
# Review len 15
# Review len 7
# Review len 13
# Review len 14
# Review len 16
# Review len 11
# Review len 24
# Review len 14
# Review len 14
# Review len 12
# Review len 9
# Review len 17
# Review len 18
# Review len 16
# Review len 18
# Review len 10
# Review len 13
# Review len 16
# Review len 14
# Review len 21
# Review len 24
# Review len 14
# Review len 13
# Review len 19
# Review len 8
# Review len 16
# Review len 16
# Review len 13
# Review len 9
# Review len 20
# Review len 12
# Review len 11
# Review len 17
# Review len 16
# Review len 10
# Review len 7
# Review len 11
# Review len 12
# Review len 9
# Review len 13
# Review len 15
# Review len 19
# Review len 6
# Review len 17
# Review len 13
# Review len 10
# Review len 17
# Review len 16
# Review len 14
# Review len 23
# Review len 14
# Review len 8
# Review len 20
# Review len 10
# Review len 18
# Review len 55
# Review len 8
# Review len 10
# Review len 19
# Review len 17
# Review len 15
# Review len 11
# Review len 19
# Review len 11
# Review len 7
# Review len 11
# Review len 14
# Review len 19
# Review len 7
# Review len 15
# Review len 22
# Review len 18
# Review len 7
# Review len 21
# Review len 14
# Review len 5
# Review len 1
# Review len 14
# Review len 16
# Review len 29
# Review len 14
# Review len 15
# Review len 12
# Review len 11
# Review len 10
# Review len 17
# Review len 9
# Review len 13
# Review len 13
# Review len 16
# Review len 1
# Review len 9
# Review len 13
# Review len 12
# Review len 10
# Review len 18
# Review len 12
# Review len 15
# Review len 18
# Review len 8
# Review len 20
# Review len 8
# Review len 25
# Review len 15
# Review len 13
# Review len 9
# Review len 9
# Review len 20
# Review len 17
# Review len 2
# Review len 16
# Review len 13
# Review len 15
# Review len 15
# Review len 13
# Review len 15
# Review len 11
# Review len 12
# Review len 17
# Review len 17
# Review len 8
# Review len 18
# Review len 20
# Review len 19
# Review len 1
# Review len 8
# Review len 8
# Review len 16
# Review len 17
# Review len 11
# Review len 16
# Review len 19
# Review len 22
# Review len 8
# Review len 14
# Review len 13
# Review len 5
# Review len 2
# Review len 5
# Review len 12
# Review len 1
# Review len 19
# Review len 19
# Review len 11
# Review len 14
# Review len 19
# Review len 10
# Review len 9
# Review len 13
# Review len 10
# Review len 24
# Review len 15
# Review len 20
# Review len 14
# Review len 12
# Review len 21
# Review len 13
# Review len 15
# Review len 15
# Review len 17
# Review len 6
# Review len 15
# Review len 25
# Review len 16
# Review len 18
# Review len 17
# Review len 1
# Review len 17
# Review len 20
# Review len 15
# Review len 12
# Review len 23
# Review len 21
# Review len 13
# Review len 15
# Review len 13
# Review len 9
# Review len 22
# Review len 16
# Review len 14
# Review len 8
# Review len 17
# Review len 15
# Review len 13
# Review len 10
# Review len 10
# Review len 22
# Review len 19
# Review len 18
# Review len 13
# Review len 23
# Review len 16
# Review len 8
# Review len 12
# Review len 13
# Review len 16
# Review len 16
# Review len 9
# Review len 18
# Review len 19
# Review len 14
# Review len 21
# Review len 17
# Review len 35
# Review len 17
# Review len 15
# Review len 13
# Review len 16
# Review len 15
# Review len 10
# Review len 8
# Review len 20
# Review len 6
# Review len 12
# Review len 10
# Review len 1
# Review len 9
# Review len 14
# Review len 9
# Review len 20
# Review len 19
# Review len 13
# Review len 15
# Review len 6
# Review len 13
# Review len 15
# Review len 9
# Review len 14
# Review len 10
# Review len 16
# Review len 16
# Review len 15
# Review len 8
# Review len 11
# Review len 22
# Review len 15
# Review len 12
# Review len 8
# Review len 19
# Review len 18
# Review len 15
# Review len 17
# Review len 12
# Review len 7
# Review len 8
# Review len 14
# Review len 15
# Review len 15
# Review len 5
# Review len 22
# Review len 13
# Review len 7
# Review len 13
# Review len 14
# Review len 15
# Review len 17
# Review len 22
# Review len 11
# Review len 20
# Review len 8
# Review len 7
# Review len 19
# Review len 15
# Review len 14
# Review len 13
# Review len 16
# Review len 17
# Review len 18
# Review len 19
# Review len 3
# Review len 19
# Review len 18
# Review len 16
# Review len 10
# Review len 16
# Review len 16
# Review len 7
# Review len 8
# Review len 20
# Review len 14
# Review len 23
# Review len 16
# Review len 18
# Review len 14
# Review len 15
# Review len 9
# Review len 14
# Review len 9
# Review len 18
# Review len 10
# Review len 10
# Review len 18
# Review len 15
# Review len 13
# Review len 4
# Review len 9
# Review len 12
# Review len 16
# Review len 2
# Review len 9
# Review len 19
# Review len 11
# Review len 7
# Review len 10
# Review len 14
# Review len 14
# Review len 19
# Review len 26
# Review len 2
# Review len 2
# Review len 13
# Review len 9
# Review len 12
# Review len 14
# Review len 14
# Review len 22
# Review len 18
# Review len 12
# Review len 15
# Review len 14
# Review len 20
# Review len 11
# Review len 13
# Review len 14
# Review len 16
# Review len 12
# Review len 13
# Review len 14
# Review len 16
# Review len 9
# Review len 12
# Review len 18
# Review len 14
# Review len 14
# Review len 17
# Review len 14
# Review len 8
# Review len 16
# Review len 15
# Review len 15
# Review len 15
# Review len 15
# Review len 25
# Review len 9
# Review len 6
# Review len 18
# Review len 1
# Review len 11
# Review len 13
# Review len 12
# Review len 7
# Review len 8
# Review len 14
# Review len 16
# Review len 14
# Review len 15
# Review len 16
# Review len 14
# Review len 11
# Review len 17
# Review len 17
# Review len 23
# Review len 14
# Review len 7
# Review len 11
# Review len 18
# Review len 12
# Review len 13
# Review len 14
# Review len 15
# Review len 0
# Review len 22
# Review len 7
# Review len 6
# Review len 18
# Review len 22
# Review len 14
# Review len 12
# Review len 11
# Review len 17
# Review len 15
# Review len 10
# Review len 21
# Review len 12
# Review len 8
# Review len 12
# Review len 13
# Review len 13
# Review len 11
# Review len 13
# Review len 10
# Review len 16
# Review len 16
# Review len 4
# Review len 22
# Review len 8
# Review len 17
# Review len 15
# Review len 4
# Review len 22
# Review len 12
# Review len 14
# Review len 15
# Review len 10
# Review len 15
# Review len 18
# Review len 12
# Review len 20
# Review len 7
# Review len 18
# Review len 22
# Review len 11
# Review len 16
# Review len 12
# Review len 11
# Review len 18
# Review len 4
# Review len 12
# Review len 14
# Review len 19
# Review len 8
# Review len 21
# Review len 15
# Review len 15
# Review len 14
# Review len 22
# Review len 12
# Review len 9
# Review len 15
# Review len 18
# Review len 14
# Review len 12
# Review len 15
# Review len 22
# Review len 13
# Review len 11
# Review len 15
# Review len 19
# Review len 1
# Review len 14
# Review len 17
# Review len 9
# Review len 13
# Review len 15
# Review len 14
# Review len 10
# Review len 15
# Review len 20
# Review len 15
# Review len 8
# Review len 11
# Review len 17
# Review len 17
# Review len 16
# Review len 21
# Review len 17
# Review len 16
# Review len 16
# Review len 19
# Review len 13
# Review len 16
# Review len 10
# Review len 20
# Review len 0
# Review len 12
# Review len 12
# Review len 12
# Review len 10
# Review len 18
# Review len 19
# Review len 10
# Review len 15
# Review len 15
# Review len 24
# Review len 16
# Review len 13
# Review len 8
# Review len 25
# Review len 12
# Review len 12
# Review len 9
# Review len 9
# Review len 15
# Review len 19
# Review len 13
# Review len 14
# Review len 1
# Review len 0
# Review len 22
# Review len 18
# Review len 14
# Review len 10
# Review len 10
# Review len 25
# Review len 17
# Review len 16
# Review len 20
# Review len 16
# Review len 16
# Review len 16
# Review len 13
# Review len 14
# Review len 21
# Review len 11
# Review len 21
# Review len 2
# Review len 20
# Review len 6
# Review len 8
# Review len 15
# Review len 10
# Review len 14
# Review len 11
# Review len 14
# Review len 34
# Review len 15
# Review len 14
# Review len 14
# Review len 9
# Review len 11
# Review len 15
# Review len 15
# Review len 10
# Review len 9
# Review len 13
# Review len 17
# Review len 16
# Review len 1
# Review len 18
# Review len 12
# Review len 18
# Review len 16
# Review len 1
# Review len 24
# Review len 15
# Review len 19
# Review len 10
# Review len 19
# Review len 14
# Review len 11
# Review len 10
# Review len 7
# Review len 15
# Review len 13
# Review len 17
# Review len 12
# Review len 1
# Review len 19
# Review len 24
# Review len 17
# Review len 14
# Review len 16
# Review len 9
# Review len 14
# Review len 15
# Review len 14
# Review len 16
# Review len 14
# Review len 29
# Review len 23
# Review len 7
# Review len 6
# Review len 17
# Review len 16
# Review len 22
# Review len 19
# Review len 18
# Review len 17
# Review len 18
# Review len 0
# Review len 20
# Review len 20
# Review len 11
# Review len 15
# Review len 14
# Review len 16
# Review len 13
# Review len 8
# Review len 11
# Review len 20
# Review len 14
# Review len 16
# Review len 12
# Review len 10
# Review len 12
# Review len 12
# Review len 4
# Review len 9
# Review len 13
# Review len 16
# Review len 16
# Review len 17
# Review len 17
# Review len 10
# Review len 10
# Review len 22
# Review len 12
# Review len 17
# Review len 18
# Review len 15
# Review len 14
# Review len 13
# Review len 14
# Review len 16
# Review len 15
# Review len 14
# Review len 5
# Review len 20
# Review len 23
# Review len 16
# Review len 12
# Review len 12
# Review len 10
# Review len 15
# Review len 20
# Review len 19
# Review len 13
# Review len 13
# Review len 16
# Review len 8
# Review len 18
# Review len 17
# Review len 18
# Review len 26
# Review len 19
# Review len 16
# Review len 15
# Review len 9
# Review len 17
# Review len 17
# Review len 14
# Review len 7
# Review len 19
# Review len 18
# Review len 11
# Review len 24
# Review len 11
# Review len 20
# Review len 9
# Review len 2
# Review len 18
# Review len 11
# Review len 13
# Review len 15
# Review len 14
# Review len 18
# Review len 11
# Review len 12
# Review len 5
# Review len 12
# Review len 10
# Review len 1
# Review len 17
# Review len 11
# Review len 18
# Review len 14
# Review len 18
# Review len 14
# Review len 14
# Review len 11
# Review len 17
# Review len 12
# Review len 1
# Review len 8
# Review len 29
# Review len 16
# Review len 15
# Review len 10
# Review len 0
# Review len 10
# Review len 9
# Review len 11
# Review len 13
# Review len 11
# Review len 16
# Review len 19
# Review len 11
# Review len 15
# Review len 15
# Review len 16
# Review len 9
# Review len 16
# Review len 12
# Review len 10
# Review len 21
# Review len 9
# Review len 16
# Review len 21
# Review len 14
# Review len 14
# Review len 10
# Review len 16
# Review len 1
# Review len 10
# Review len 17
# Review len 20
# Review len 10
# Review len 4
# Review len 20
# Review len 7
# Review len 2
# Review len 15
# Review len 22
# Review len 14
# Review len 19
# Review len 13
# Review len 15
# Review len 26
# Review len 17
# Review len 14
# Review len 1
# Review len 19
# Review len 20
# Review len 16
# Review len 10
# Review len 14
# Review len 17
# Review len 1
# Review len 13
# Review len 12
# Review len 16
# Review len 20
# Review len 11
# Review len 11
# Review len 15
# Review len 16
# Review len 20
# Review len 16
# Review len 15
# Review len 23
# Review len 15
# Review len 16
# Review len 14
# Review len 24
# Review len 11
# Review len 15
# Review len 16
# Review len 12
# Review len 13
# Review len 16
# Review len 13
# Review len 13
# Review len 10
# Review len 12
# Review len 12
# Review len 9
# Review len 17
# Review len 16
# Review len 2
# Review len 19
# Review len 18
# Review len 15
# Review len 11
# Review len 13
# Review len 20
# Review len 5
# Review len 7
# Review len 2
# Review len 32
# Review len 13
# Review len 11
# Review len 14
# Review len 1
# Review len 13
# Review len 24
# Review len 17
# Review len 12
# Review len 14
# Review len 10
# Review len 11
# Review len 8
# Review len 18
# Review len 13
# Review len 11
# Review len 15
# Review len 22
# Review len 22
# Review len 15
# Review len 13
# Review len 10
# Review len 17
# Review len 14
# Review len 12
# Review len 15
# Review len 15
# Review len 12
# Review len 11
# Review len 13
# Review len 18
# Review len 19
# Review len 16
# Review len 15
# Review len 13
# Review len 13
# Review len 7
# Review len 16
# Review len 6
# Review len 18
# Review len 15
# Review len 7
# Review len 15
# Review len 11
# Review len 7
# Review len 12
# Review len 12
# Review len 11
# Review len 18
# Review len 15
# Review len 17
# Review len 14
# Review len 1
# Review len 19
# Review len 14
# Review len 9
# Review len 17
# Review len 15
# Review len 16
# Review len 13
# Review len 13
# Review len 15
# Review len 11
# Review len 11
# Review len 14
# Review len 7
# Review len 14
# Review len 20
# Review len 10
# Review len 16
# Review len 19
# Review len 6
# Review len 9
# Review len 14
# Review len 14
# Review len 16
# Review len 9
# Review len 17
# Review len 22
# Review len 15
# Review len 19
# Review len 11
# Review len 22
# Review len 9
# Review len 19
# Review len 17
# Review len 12
# Review len 16
# Review len 15
# Review len 13
# Review len 8
# Review len 15
# Review len 14
# Review len 15
# Review len 8
# Review len 8
# Review len 13
# Review len 10
# Review len 2
# Review len 17
# Review len 16
# Review len 15
# Review len 10
# Review len 20
# Review len 20
# Review len 17
# Review len 21
# Review len 8
# Review len 12
# Review len 28
# Review len 16
# Review len 15
# Review len 19
# Review len 17
# Review len 11
# Review len 13
# Review len 18
# Review len 15
# Review len 13
# Review len 14
# Review len 14
# Review len 12
# Review len 1
# Review len 8
# Review len 18
# Review len 12
# Review len 9
# Review len 10
# Review len 13
# Review len 12
# Review len 20
# Review len 10
# Review len 15
# Review len 14
# Review len 9
# Review len 13
# Review len 18
# Review len 12
# Review len 19
# Review len 8
# Review len 10
# Review len 23
# Review len 16
# Review len 24
# Review len 18
# Review len 15
# Review len 15
# Review len 13
# Review len 13
# Review len 16
# Review len 14
# Review len 11
# Review len 10
# Review len 15
# Review len 16
# Review len 16
# Review len 18
# Review len 18
# Review len 16
# Review len 11
# Review len 11
# Review len 16
# Review len 17
# Review len 19
# Review len 15
# Review len 23
# Review len 2
# Review len 8
# Review len 8
# Review len 11
# Review len 24
# Review len 12
# Review len 13
# Review len 11
# Review len 19
# Review len 17
# Review len 18
# Review len 16
# Review len 18
# Review len 7
# Review len 19
# Review len 2
# Review len 20
# Review len 15
# Review len 15
# Review len 12
# Review len 15
# Review len 15
# Review len 14
# Review len 12
# Review len 16
# Review len 23
# Review len 1
# Review len 5
# Review len 9
# Review len 17
# Review len 16
# Review len 15
# Review len 12
# Review len 17
# Review len 16
# Review len 10
# Review len 12
# Review len 0
# Review len 16
# Review len 7
# Review len 18
# Review len 5
# Review len 17
# Review len 2
# Review len 15
# Review len 19
# Review len 18
# Review len 13
# Review len 15
# Review len 15
# Review len 14
# Review len 9
# Review len 12
# Review len 2
# Review len 14
# Review len 17
# Review len 19
# Review len 17
# Review len 17
# Review len 18
# Review len 13
# Review len 9
# Review len 17
# Review len 22
# Review len 12
# Review len 8
# Review len 11
# Review len 17
# Review len 9
# Review len 14
# Review len 10
# Review len 5
# Review len 11
# Review len 15
# Review len 19
# Review len 9
# Review len 20
# Review len 18
# Review len 11
# Review len 19
# Review len 16
# Review len 17
# Review len 17
# Review len 10
# Review len 10
# Review len 13
# Review len 6
# Review len 11
# Review len 13
# Review len 16
# Review len 14
# Review len 8
# Review len 17
# Review len 8
# Review len 12
# Review len 9
# Review len 10
# Review len 12
# Review len 6
# Review len 12
# Review len 16
# Review len 17
# Review len 15
# Review len 19
# Review len 14
# Review len 17
# Review len 15
# Review len 14
# Review len 6
# Review len 12
# Review len 18
# Review len 14
# Review len 17
# Review len 17
# Review len 11
# Review len 16
# Review len 20
# Review len 9
# Review len 15
# Review len 58
# Review len 13
# Review len 12
# Review len 18
# Review len 15
# Review len 16
# Review len 17
# Review len 25
# Review len 14
# Review len 12
# Review len 23
# Review len 16
# Review len 14
# Review len 5
# Review len 14
# Review len 20
# Review len 12
# Review len 18
# Review len 12
# Review len 16
# Review len 13
# Review len 16
# Review len 13
# Review len 12
# Review len 12
# Review len 17
# Review len 14
# Review len 20
# Review len 16
# Review len 18
# Review len 23
# Review len 10
# Review len 16
# Review len 14
# Review len 13
# Review len 13
# Review len 6
# Review len 16
# Review len 18
# Review len 16
# Review len 1
# Review len 18
# Review len 14
# Review len 19
# Review len 18
# Review len 16
# Review len 14
# Review len 1
# Review len 15
# Review len 10
# Review len 14
# Review len 13
# Review len 15
# Review len 10
# Review len 15
# Review len 14
# Review len 13
# Review len 19
# Review len 16
# Review len 20
# Review len 17
# Review len 3
# Review len 17
# Review len 14
# Review len 1
# Review len 9
# Review len 13
# Review len 13
# Review len 17
# Review len 26
# Review len 15
# Review len 10
# Review len 13
# Review len 20
# Review len 18
# Review len 20
# Review len 15
# Review len 24
# Review len 26
# Review len 11
# Review len 7
# Review len 21
# Review len 11
# Review len 16
# Review len 15
# Review len 2
# Review len 13
# Review len 12
# Review len 8
# Review len 17
# Review len 10
# Review len 11
# Review len 15
# Review len 16
# Review len 17
# Review len 19
# Review len 12
# Review len 16
# Review len 17
# Review len 6
# Review len 15
# Review len 10
# Review len 17
# Review len 10
# Review len 7
# Review len 16
# Review len 17
# Review len 11
# Review len 18
# Review len 15
# Review len 20
# Review len 19
# Review len 8
# Review len 17
# Review len 15
# Review len 17
# Review len 10
# Review len 14
# Review len 8
# Review len 18
# Review len 16
# Review len 15
# Review len 13
# Review len 8
# Review len 16
# Review len 12
# Review len 23
# Review len 12
# Review len 13
# Review len 9
# Review len 11
# Review len 11
# Review len 18
# Review len 20
# Review len 16
# Review len 17
# Review len 21
# Review len 13
# Review len 16
# Review len 17
# Review len 17
# Review len 14
# Review len 12
# Review len 5
# Review len 4
# Review len 11
# Review len 16
# Review len 13
# Review len 18
# Review len 9
# Review len 19
# Review len 13
# Review len 16
# Review len 0
# Review len 14
# Review len 12
# Review len 15
# Review len 13
# Review len 10
# Review len 16
# Review len 11
# Review len 22
# Review len 22
# Review len 10
# Review len 19
# Review len 10
# Review len 14
# Review len 16
# Review len 19
# Review len 12
# Review len 14
# Review len 13
# Review len 21
# Review len 20
# Review len 10
# Review len 9
# Review len 11
# Review len 13
# Review len 13
# Review len 12
# Review len 14
# Review len 19
# Review len 1
# Review len 15
# Review len 3
# Review len 12
# Review len 16
# Review len 13
# Review len 21
# Review len 14
# Review len 15
# Review len 15
# Review len 13
# Review len 11
# Review len 9
# Review len 15
# Review len 15
# Review len 16
# Review len 20
# Review len 14
# Review len 10
# Review len 12
# Review len 13
# Review len 13
# Review len 14
# Review len 14
# Review len 16
# Review len 6
# Review len 10
# Review len 14
# Review len 18
# Review len 17
# Review len 12
# Review len 10
# Review len 16
# Review len 17
# Review len 13
# Review len 17
# Review len 29
# Review len 20
# Review len 13
# Review len 13
# Review len 6
# Review len 3
# Review len 13
# Review len 14
# Review len 19
# Review len 12
# Review len 19
# Review len 15
# Review len 13
# Review len 22
# Review len 9
# Review len 13
# Review len 13
# Review len 11
# Review len 18
# Review len 18
# Review len 22
# Review len 14
# Review len 13
# Review len 19
# Review len 16
# Review len 11
# Review len 18
# Review len 11
# Review len 16
# Review len 16
# Review len 8
# Review len 0
# Review len 13
# Review len 19
# Review len 19
# Review len 7
# Review len 13
# Review len 12
# Review len 12
# Review len 13
# Review len 13
# Review len 10
# Review len 18
# Review len 12
# Review len 11
# Review len 11
# Review len 8
# Review len 14
# Review len 10
# Review len 15
# Review len 17
# Review len 8
# Review len 17
# Review len 16
# Review len 14
# Review len 6
# Review len 20
# Review len 9
# Review len 9
# Review len 21
# Review len 14
# Review len 15
# Review len 17
# Review len 11
# Review len 14
# Review len 10
# Review len 21
# Review len 15
# Review len 11
# Review len 15
# Review len 1
# Review len 19
# Review len 16
# Review len 13
# Review len 15
# Review len 14
# Review len 18
# Review len 13
# Review len 23
# Review len 18
# Review len 13
# Review len 19
# Review len 6
# Review len 15
# Review len 18
# Review len 10
# Review len 19
# Review len 20
# Review len 11
# Review len 0
# Review len 21
# Review len 8
# Review len 12
# Review len 13
# Review len 17
# Review len 10
# Review len 1
# Review len 11
# Review len 7
# Review len 29
# Review len 12
# Review len 13
# Review len 10
# Review len 10
# Review len 11
# Review len 21
# Review len 18
# Review len 14
# Review len 19
# Review len 22
# Review len 17
# Review len 21
# Review len 14
# Review len 12
# Review len 11
# Review len 19
# Review len 15
# Review len 6
# Review len 18
# Review len 13
# Review len 10
# Review len 4
# Review len 15
# Review len 16
# Review len 8
# Review len 10
# Review len 14
# Review len 4
# Review len 19
# Review len 18
# Review len 11
# Review len 14
# Review len 10
# Review len 17
# Review len 16
# Review len 10
# Review len 14
# Review len 15
# Review len 13
# Review len 16
# Review len 7
# Review len 15
# Review len 13
# Review len 10
# Review len 11
# Review len 13
# Review len 14
# Review len 13
# Review len 19
# Review len 16
# Review len 17
# Review len 18
# Review len 22
# Review len 10
# Review len 16
# Review len 21
# Review len 15
# Review len 8
# Review len 2
# Review len 22
# Review len 15
# Review len 24
# Review len 9
# Review len 13
# Review len 12
# Review len 7
# Review len 2
# Review len 18
# Review len 12
# Review len 2
# Review len 10
# Review len 9
# Review len 16
# Review len 16
# Review len 19
# Review len 15
# Review len 12
# Review len 13
# Review len 17
# Review len 15
# Review len 9
# Review len 13
# Review len 11
# Review len 22
# Review len 14
# Review len 13
# Review len 16
# Review len 5
# Review len 21
# Review len 13
# Review len 12
# Review len 16
# Review len 16
# Review len 14
# Review len 11
# Review len 20
# Review len 2
# Review len 21
# Review len 10
# Review len 12
# Review len 15
# Review len 15
# Review len 19
# Review len 9
# Review len 20
# Review len 18
# Review len 15
# Review len 17
# Review len 18
# Review len 13
# Review len 1
# Review len 25
# Review len 18
# Review len 17
# Review len 14
# Review len 11
# Review len 17
# Review len 12
# Review len 14
# Review len 13
# Review len 18
# Review len 12
# Review len 19
# Review len 16
# Review len 9
# Review len 16
# Review len 6
# Review len 11
# Review len 10
# Review len 17
# Review len 16
# Review len 8
# Review len 18
# Review len 16
# Review len 17
# Review len 10
# Review len 18
# Review len 27
# Review len 19
# Review len 9
# Review len 15
# Review len 13
# Review len 13
# Review len 13
# Review len 17
# Review len 9
# Review len 14
# Review len 16
# Review len 18
# Review len 10
# Review len 18
# Review len 17
# Review len 16
# Review len 14
# Review len 25
# Review len 15
# Review len 23
# Review len 18
# Review len 20
# Review len 8
# Review len 17
# Review len 16
# Review len 19
# Review len 15
# Review len 12
# Review len 14
# Review len 9
# Review len 17
# Review len 17
# Review len 20
# Review len 15
# Review len 12
# Review len 25
# Review len 12
# Review len 13
# Review len 18
# Review len 9
# Review len 19
# Review len 17
# Review len 22
# Review len 15
# Review len 15
# Review len 12
# Review len 13
# Review len 12
# Review len 14
# Review len 2
# Review len 19
# Review len 14
# Review len 12
# Review len 3
# Review len 10
# Review len 8
# Review len 19
# Review len 13
# Review len 8
# Review len 14
# Review len 14
# Review len 19
# Review len 19
# Review len 21
# Review len 12
# Review len 14
# Review len 15
# Review len 12
# Review len 15
# Review len 15
# Review len 21
# Review len 19
# Review len 25
# Review len 22
# Review len 19
# Review len 11
# Review len 21
# Review len 13
# Review len 13
# Review len 26
# Review len 17
# Review len 22
# Review len 13
# Review len 18
# Review len 16
# Review len 16
# Review len 13
# Review len 21
# Review len 10
# Review len 17
# Review len 22
# Review len 19
# Review len 12
# Review len 13
# Review len 25
# Review len 16
# Review len 14
# Review len 12
# Review len 16
# Review len 10
# Review len 14
# Review len 14
# Review len 7
# Review len 13
# Review len 2
# Review len 9
# Review len 1
# Review len 17
# Review len 14
# Review len 7
# Review len 11
# Review len 5
# Review len 17
# Review len 13
# Review len 19
# Review len 17
# Review len 2
# Review len 10
# Review len 9
# Review len 8
# Review len 14
# Review len 14
# Review len 12
# Review len 16
# Review len 4
# Review len 17
# Review len 11
# Review len 13
# Review len 17
# Review len 18
# Review len 16
# Review len 7
# Review len 15
# Review len 17
# Review len 10
# Review len 9
# Review len 8
# Review len 14
# Review len 16
# Review len 16
# Review len 13
# Review len 15
# Review len 16
# Review len 16
# Review len 11
# Review len 14
# Review len 17
# Review len 12
# Review len 14
# Review len 5
# Review len 8
# Review len 17
# Review len 10
# Review len 25
# Review len 5
# Review len 14
# Review len 18
# Review len 20
# Review len 20
# Review len 9
# Review len 22
# Review len 16
# Review len 15
# Review len 15
# Review len 18
# Review len 11
# Review len 8
# Review len 16
# Review len 18
# Review len 14
# Review len 13
# Review len 19
# Review len 8
# Review len 11
# Review len 11
# Review len 18
# Review len 20
# Review len 13
# Review len 26
# Review len 18
# Review len 11
# Review len 18
# Review len 14
# Review len 18
# Review len 16
# Review len 15
# Review len 17
# Review len 11
# Review len 9
# Review len 13
# Review len 13
# Review len 15
# Review len 14
# Review len 12
# Review len 19
# Review len 6
# Review len 15
# Review len 15
# Review len 12
# Review len 16
# Review len 20
# Review len 11
# Review len 14
# Review len 22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[149], line 8
#       4 from torchtext.vocab import build_vocab_from_iterator
#       6 tokenizer = get_tokenizer("basic_english")
# ----> 8 corpus = construct_corpus(X_train)
#       9 corpus_test = construct_corpus(X_test)
#      10 corpus_val = construct_corpus(X_val)
#
# Cell In[148], line 20, in construct_corpus(data)
#      18 review = review.split()
#      19 print("Review len", len(review))
# ---> 20 review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
#      21 review = ' '.join(review)
#      22 # review = measure_time(lambda: re.sub('[^a-zA-Z]', ' ', data['total'].iloc[i]), "resub")()
#      23 # review = measure_time(lambda: review.lower(), "lower")()
#      24 # review = measure_time(lambda: review.split(), "split")()
#      25 # review = measure_time(lambda: [ps.stem(word) for word in review if not word in stopwords.words('english')], "stopwords")()
#      26 # review = measure_time(lambda: ' '.join(review), "join")()
#
# Cell In[148], line 20, in <listcomp>(.0)
#      18 review = review.split()
#      19 print("Review len", len(review))
# ---> 20 review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
#      21 review = ' '.join(review)
#      22 # review = measure_time(lambda: re.sub('[^a-zA-Z]', ' ', data['total'].iloc[i]), "resub")()
#      23 # review = measure_time(lambda: review.lower(), "lower")()
#      24 # review = measure_time(lambda: review.split(), "split")()
#      25 # review = measure_time(lambda: [ps.stem(word) for word in review if not word in stopwords.words('english')], "stopwords")()
#      26 # review = measure_time(lambda: ' '.join(review), "join")()
#
# File ~/.ml_python_venv/lib/python3.11/site-packages/nltk/stem/porter.py:654, in PorterStemmer.stem(self, word, to_lowercase)
#     640     """Implements Step 5a from "An algorithm for suffix stripping"
#     641
#     642     From the paper:
#    (...)
#     648                                 roll           ->  roll
#     649     """
#     650     return self._apply_rule_list(
#     651         word, [("ll", "l", lambda stem: self._measure(word[:-1]) > 1)]
#     652     )
# --> 654 def stem(self, word, to_lowercase=True):
#     655     """
#     656     :param to_lowercase: if `to_lowercase=True` the word always lowercase
#     657     """
#     658     stem = word.lower() if to_lowercase else word
#
# KeyboardInterrupt:

# %%
# def one_hot_tokens(voc, tokens):
#     voc_tokens = [t.tensor(voc(token), dtype=t.int64) for token in tokens]
#     return [F.one_hot(t, num_classes = len(voc)) for t in voc_tokens]
# one_hot = one_hot_tokens(voc, tokens)
# one_hot_test = one_hot_tokens(voc, tokens_test)

# %%
from tqdm.auto import tqdm

max_len = 25
#
# def padding_tensor(one_hot_t):
#     embedding = []
#     for i in tqdm(range(len(one_hot_t))):
#         embedding.append(nn.ConstantPad2d((0, 0, max_len - one_hot_t[i].shape[0], 0), 0)(one_hot_t[i]))
#     return t.stack(embedding)

def padding_indexes(tokens):
    embedding = []
    for token in tqdm(tokens):
        embedding.append(nn.ConstantPad1d((max_len - len(token), 0), 0)(t.tensor(token, dtype=t.int64)))
    return t.stack(embedding)
    
# embedded_docs = padding_tensor(one_hot)
# embedded_docs_test = padding_tensor(one_hot_test)

padded_tokens = padding_indexes(voc_tokens)
padded_tokens_val = padding_indexes(voc_tokens_val)
padded_tokens_test = padding_indexes(voc_tokens_test)
# Out:
#   0%|          | 0/16640 [00:00<?, ?it/s]
# /var/folders/3_/r1n3j5793rn8qxqk1d1p9cbh0000gn/T/ipykernel_34150/3465826615.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   embedding.append(nn.ConstantPad1d((max_len - len(token), 0), 0)(t.tensor(token, dtype=t.int64)))
#   0%|          | 0/4160 [00:00<?, ?it/s]
#   0%|          | 0/5200 [00:00<?, ?it/s]

# %% [markdown]
# ## Model description + training

# %%
class FakeNewsClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, n_layers, dropout):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)#, padding_idx=0)
        self.dropout_1 = nn.Dropout(dropout)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=n_layers, batch_first=True)
        self.dropout_2 = nn.Dropout(dropout)
        self.dense = nn.Linear(hidden_dim, 64)
        self.dropout_3 = nn.Dropout(dropout)
        self.out = nn.Linear(64, 1)
        
    def forward(self, x):
        x = self.embedding(x)
        x = self.dropout_1(x)
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.dropout_2(x)
        x = t.relu(self.dense(x))
        x = self.dropout_3(x)
        x = t.sigmoid(self.out(x))
        return x

# %%
class TokensDataset(Dataset):
    def __init__(self, X, y, device):
        self.X = X.to(device)
        self.y = t.tensor(y).float().to(device)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
device = optimal_device()
print(f"Device: {device}")
# Out:
# Device: mps

# %%
# setup
batch_size = 64
train_dataset = TokensDataset(padded_tokens, y_train.values, device)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataset = TokensDataset(padded_tokens_val, y_val.values, device)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

loss = nn.BCELoss()
model = FakeNewsClassifier(voc_size, 40, 100, 2, 0.3).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def accuracy(model, test_dataloader):
    model.eval()
    with t.no_grad():
        sum_acc = 0
        for batch in test_dataloader:
            X, y = batch
            y_pred = model(X)
            y_pred = y_pred.squeeze()
            sum_acc += t.sum((y_pred > 0.5) == y)
        return sum_acc / (len(test_dataloader) * test_dataloader.batch_size)

def train(model, dataloader, test_dataloader, loss, optimizer, epochs):
    print(f"Staring acc_train: {accuracy(model, dataloader)} acc_val: {accuracy(model, test_dataloader)}")

    for epoch in range(epochs):
        model.train()
        l = 0
        for batch in dataloader:
            X, y = batch
            optimizer.zero_grad()
            y_pred = model(X)
            y_pred = y_pred.squeeze()
            l = loss(y_pred, y)
            l.backward()
            optimizer.step()

        train_acc = accuracy(model, dataloader)
        val_acc = accuracy(model, test_dataloader)

        print(f"Epoch {epoch+1} loss: {l.item()} acc_train: {train_acc} acc_val: {val_acc}")

# %%
train(model, train_dataloader, val_dataloader, loss, optimizer, 5)
# Out:
# Staring acc_train: 0.50390625 acc_val: 0.48750001192092896
# Epoch 1 loss: 0.19220766425132751 acc_train: 0.9737379550933838 acc_val: 0.96875
# Epoch 2 loss: 0.0719328299164772 acc_train: 0.9912259578704834 acc_val: 0.9872596263885498
# Epoch 3 loss: 0.006107015535235405 acc_train: 0.9958533644676208 acc_val: 0.9908654093742371
# Epoch 4 loss: 0.009487172588706017 acc_train: 0.9964542984962463 acc_val: 0.9911057949066162
# Epoch 5 loss: 0.008560552261769772 acc_train: 0.997776448726654 acc_val: 0.9923076629638672

# %%
X_val.iloc[123], y_val.iloc[123]
# Out:
# (id                                                    11547
#  title     Aussie Muslims Demand ’Safe Spaces’ so Followe...
#  author                                           Simon Kent
#  text      An Australian Islamic group wants   “safe spac...
#  total     Aussie Muslims Demand ’Safe Spaces’ so Followe...
#  Name: 11547, dtype: object,
#  0)

# %%
model.eval()
model(padded_tokens_val[123].unsqueeze(0).to(device))
# Out:
# tensor([[0.0062]], device='mps:0', grad_fn=<SigmoidBackward0>)

# %%
model.eval()

# save model

model_path = "../tmp/model.pt"
t.save(model.state_dict(), model_path)

# %%
padded_tokens_val[123].unsqueeze(0).shape
# Out:
# torch.Size([1, 25])

# %%
model(padded_tokens_test[])
